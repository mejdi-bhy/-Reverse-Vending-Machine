# %% [markdown]
# #### This lab aims to train and test an object detection model using transfer learning capable of detecting 4 classes: bottle, can, cup, nocup

# %% [markdown]
# #### This lab was inspired by this course.
# #### Course Link : https://www.youtube.com/watch?v=yqkISICHH-U&t=18602s&ab_channel=NicholasRenotte

# %% [markdown]
# #### The pretrained models used in this lab are part of the TensorFlow detection Zoo. The TensorFlow detection Zoo is a collection of pretrained object detection models trained on the COCO 2017 dataset.
# #### GitHub link : https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md

# %% [markdown]
# #### Within this lab, we will be testing diffrent pretrained models from the TensorFlow detection Zoo and some of the well known models like YOLO. The main goal is to pick up the pretrained model with the heighest accuracy.

# %% [markdown]
# #### Note : As the data collection phase is not completed yet, and as training more than one model can be computationally expensive, this lab will focus on training and testing only one pretrained model to demonstrate the hole process of training and testing an object detecting model. Once the data collection phase is completed, then we will proceede with the other models.
# #### The pretrained model implemented within this lab will be the centernet_hg104_512x512 model from the TensorFlow detection Zoo.

# %%
import os

# %%
# Downloading the pretrained centernet_hg104_512x512 object detection model
# !wget download.tensorflow.org/models/object_detection/tf2/20200713/centernet_hg104_512x512_coco17_tpu-8.tar.gz
# Out:
# --2023-05-17 17:36:06--  http://download.tensorflow.org/models/object_detection/tf2/20200713/centernet_hg104_512x512_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.125.128, 2607:f8b0:4001:c2f::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.125.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1426099846 (1.3G) [application/x-tar]
# Saving to: ‘centernet_hg104_512x512_coco17_tpu-8.tar.gz’
#
# centernet_hg104_512 100%[===================>]   1.33G   248MB/s    in 5.6s
#
# 2023-05-17 17:36:12 (243 MB/s) - ‘centernet_hg104_512x512_coco17_tpu-8.tar.gz’ saved [1426099846/1426099846]

# %%
# Extracting the .tar.gz file of the pretrained_model 
# !tar -zxvf centernet_hg104_512x512_coco17_tpu-8.tar.gz
# Out:
# centernet_hg104_512x512_coco17_tpu-8/
# centernet_hg104_512x512_coco17_tpu-8/checkpoint/
# centernet_hg104_512x512_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# centernet_hg104_512x512_coco17_tpu-8/checkpoint/checkpoint
# centernet_hg104_512x512_coco17_tpu-8/checkpoint/ckpt-0.index
# centernet_hg104_512x512_coco17_tpu-8/pipeline.config
# centernet_hg104_512x512_coco17_tpu-8/saved_model/
# centernet_hg104_512x512_coco17_tpu-8/saved_model/saved_model.pb
# centernet_hg104_512x512_coco17_tpu-8/saved_model/assets/
# centernet_hg104_512x512_coco17_tpu-8/saved_model/variables/
# centernet_hg104_512x512_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# centernet_hg104_512x512_coco17_tpu-8/saved_model/variables/variables.index

# %%
# Removing the .tar.gz file of the pretrained_model (no need for the compressed file of the model)
# !rm centernet_hg104_512x512_coco17_tpu-8.tar.gz

# %% [markdown]
# #### Training an object detection model consists of feeding the model with a bunch of annotated (labeled) images to learn from. Annotating(labeling) an image refers to drawing a bounding box around the object we want to detect and specifying the label(class) of that object. In our case, we have 4 classes(labels) that we want our model to detect(bottle, can, cup, nocup).
# #### To annotate (label) collected images, we used a tool named labelImg. Annotating (labeling) the images will generate a .xml file for each annotated(labeled) image.
# #### You can learn more about labeling images and the labelImg tool that we used to annotate images from the course (course link above). you can skip to the  Labelling Images for Object Detection using LabelImg part at 1:04:11.

# %%
# Importing the labeled(annotated) images that will be used to train and test the object detection model
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Just Copying the dataset compressed file from the drive folder to the main folder (/content/)
# The dataset contains the train and test datasets that contains respectively the labeled(annotated) images for training and testing the object detection model
# !cp drive/MyDrive/dataset_for_object_detection_model.zip .

# %%
# !cp drive/MyDrive/object_detection_model.zip .

# %%
# Unzipping the dataset compressed file
# !unzip dataset_for_object_detection_model.zip
# Out:
# Archive:  object_detection_model.zip
#    creating: object_detection_model/
#   inflating: object_detection_model/pipeline.config
#    creating: object_detection_model/saved_model/
#    creating: object_detection_model/saved_model/variables/
#   inflating: object_detection_model/saved_model/variables/variables.index
#   inflating: object_detection_model/saved_model/variables/variables.data-00000-of-00001
#    creating: object_detection_model/saved_model/assets/
#   inflating: object_detection_model/saved_model/saved_model.pb
#  extracting: object_detection_model/saved_model/fingerprint.pb
#    creating: object_detection_model/checkpoint/
#   inflating: object_detection_model/checkpoint/ckpt-0.data-00000-of-00001
#   inflating: object_detection_model/checkpoint/ckpt-0.index
#   inflating: object_detection_model/checkpoint/checkpoint
#   inflating: object_detection_model/label_map.pbtxt

# %%
# Remove the  compressed dataset file(no need for the compressed files)
# !rm dataset_for_object_detection_model.zip

# %% [markdown]
# ### Generating TF Records :
# #### TF Records are binary file format for storing data.
# #### Until now we possess a bunch of .jpg images along with .xml files generated from annotating these images. We said that training an object detection model consists of feeding the model with a bunch of annotated (labeled) images to learn from. But until this moment, we still have the images and their annotations as 2 seprate files. And here comes the TF Records as a combination of the images and their annotations in one single data structure.
# #### + Using TF Records speed up training for your custom object detection model.

# %% [markdown]
# #### Before we can generate these TF Records, we need to create a label_map file in which we map each label (bottle, cup, nocup, can) to an integer (1, 2, 3, 4). This label_map file will be used to generate the TF Records, and then the TF Records will be used to train and test the model.

# %%
# Let's start with creating the label_map.pbtxt file
# !touch label_map.pbtxt

# %%
# Mapping each label to an integer
# We can do this manually : just open the label_map.pbtxt file manually and add what's inside the brackets:
"""
item {
	name:'bottle'
	id:1
}

item {
	name:'cup'
	id:2
}

item {
	name:'nocup'
	id:3
}

item {
	name:'can'
	id:4
}
"""

# %%
# Cloning the tenorflow model garden repository from GitHub. This repo contains 
# a bunch of tools and modeling solutions that will be used to genrate the TF 
# Records and will be used later to train and test the model
# !git clone https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 85559, done.
# remote: Counting objects: 100% (1158/1158), done.
# remote: Compressing objects: 100% (453/453), done.
# remote: Total 85559 (delta 713), reused 1110 (delta 699), pack-reused 84401
# Receiving objects: 100% (85559/85559), 598.65 MiB | 34.94 MiB/s, done.
# Resolving deltas: 100% (61220/61220), done.

# %%
# installing the object_detection dependency from the cloned repository
# !cd models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/models/research
#   Preparing metadata (setup.py) ... done
# Collecting avro-python3 (from object-detection==0.1)
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Collecting apache-beam (from object-detection==0.1)
#   Downloading apache_beam-2.47.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 61.5 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (8.4.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (4.9.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (3.7.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (0.29.34)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (0.6.0.post1)
# Requirement already satisfied: tf-slim in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.0.6)
# Collecting lvis (from object-detection==0.1)
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.5.3)
# Collecting tf-models-official>=2.5.1 (from object-detection==0.1)
#   Downloading tf_models_official-2.12.0-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 68.3 MB/s eta 0:00:00
# Collecting tensorflow_io (from object-detection==0.1)
#   Downloading tensorflow_io-0.32.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (28.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.0/28.0 MB 39.1 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.12.0)
# Collecting pyparsing==2.4.7 (from object-detection==0.1)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.2 MB/s eta 0:00:00
# Collecting sacrebleu<=2.2.0 (from object-detection==0.1)
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 15.8 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2022.10.31)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.8.10)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.22.4)
# Collecting colorama (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.84.0)
# Collecting immutabledict (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading immutabledict-2.2.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.13)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (9.0.0)
# Collecting pyyaml<6.0,>=5.1 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading PyYAML-5.4.1.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 22.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sentencepiece (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.6 MB/s eta 0:00:00
# Collecting seqeval (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tensorflow-addons (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 56.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.9.2)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.13.0)
# Collecting tensorflow-model-optimization>=0.4.1 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_model_optimization-0.7.4-py2.py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 27.8 MB/s eta 0:00:00
# Collecting tensorflow-text~=2.12.0 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_text-2.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 102.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow~=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->object-detection==0.1) (2022.7.1)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Collecting crcmod<2.0,>=1.7 (from apache-beam->object-detection==0.1)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 13.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting orjson<4.0 (from apache-beam->object-detection==0.1)
#   Downloading orjson-3.8.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 14.5 MB/s eta 0:00:00
# Collecting dill<0.3.2,>=0.3.1.1 (from apache-beam->object-detection==0.1)
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 19.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Collecting fastavro<2,>=0.23.6 (from apache-beam->object-detection==0.1)
#   Downloading fastavro-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 108.0 MB/s eta 0:00:00
# Collecting fasteners<1.0,>=0.3 (from apache-beam->object-detection==0.1)
#   Downloading fasteners-0.18-py3-none-any.whl (18 kB)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.54.0)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache-beam->object-detection==0.1)
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: httplib2<0.22.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (0.21.0)
# Collecting objsize<0.7.0,>=0.6.1 (from apache-beam->object-detection==0.1)
#   Downloading objsize-0.6.1-py3-none-any.whl (9.3 kB)
# Collecting pymongo<5.0.0,>=3.8.0 (from apache-beam->object-detection==0.1)
#   Downloading pymongo-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 36.9 MB/s eta 0:00:00
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.22.2)
# Requirement already satisfied: protobuf<4.23.0,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (3.20.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (4.5.0)
# Collecting zstandard<1,>=0.18.0 (from apache-beam->object-detection==0.1)
#   Downloading zstandard-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 98.9 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow<12.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (9.0.0)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (23.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.32.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_io->object-detection==0.1) (0.32.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.12.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.65.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.26.15)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5.0.0,>=3.8.0->apache-beam->object-detection==0.1)
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 29.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.4)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (67.7.2)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.3.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.8)
# Collecting numpy>=1.17 (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 62.2 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: array-record in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (8.1.3)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.13.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.40.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.12.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (3.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.59.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.3.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.3.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection, avro-python3, crcmod, dill, pyyaml, seqeval, docopt
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1696986 sha256=79c91bc69fa908e788989c09b578b94cda79263eccd02422849ecbf95b7f2f54
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_q1py5yq/wheels/53/dd/70/2de274d6c443c69d367bd6a5606f95e5a6df61aacf1435ec0d
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=43994 sha256=f7be9a90cfc053bd20a263bf6448fbc8e00e75f1dc197bf03c400597e245fc37
#   Stored in directory: /root/.cache/pip/wheels/bc/85/62/6cdd81c56f923946b401cecff38055b94c9b766927f7d8ca82
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=37101 sha256=ad89d1cf41703dbbb9d74f45ec3950308c15460e0a36333cb166edd72427ead5
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78545 sha256=214e1af1e5c829ebd6e88588cf13af602318468872c8a6cbfb38257cf5323e33
#   Stored in directory: /root/.cache/pip/wheels/ea/e2/86/64980d90e297e7bf2ce588c2b96e818f5399c515c4bb8a7e4f
#   Building wheel for pyyaml (pyproject.toml) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.4.1-cp310-cp310-linux_x86_64.whl size=45658 sha256=ab20fa86b9e1e8e853df7b69fe1898bd1c568c17560ff62470d8e02d3fcf2fdb
#   Stored in directory: /root/.cache/pip/wheels/c7/0d/22/696ee92245ad710f506eee79bb05c740d8abccd3ecdb778683
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16165 sha256=afca37b4fe8512299e48d2891f339d75b38c5a7a50a908ea5b80b5e4a5cfc266
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13707 sha256=6bbfc332a8643dd5601915cf702de46c5129b110a7e64c6e5618ee033310f410
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built object-detection avro-python3 crcmod dill pyyaml seqeval docopt
# Installing collected packages: sentencepiece, docopt, crcmod, zstandard, typeguard, tensorflow_io, pyyaml, pyparsing, portalocker, orjson, objsize, numpy, immutabledict, fasteners, fastavro, dnspython, dill, colorama, avro-python3, tensorflow-model-optimization, tensorflow-addons, sacrebleu, pymongo, hdfs, apache-beam, seqeval, lvis, tensorflow-text, tf-models-official, object-detection
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# Successfully installed apache-beam-2.47.0 avro-python3-1.10.2 colorama-0.4.6 crcmod-1.7 dill-0.3.1.1 dnspython-2.3.0 docopt-0.6.2 fastavro-1.7.4 fasteners-0.18 hdfs-2.7.0 immutabledict-2.2.4 lvis-0.5.3 numpy-1.23.5 object-detection-0.1 objsize-0.6.1 orjson-3.8.12 portalocker-2.7.0 pymongo-4.3.3 pyparsing-2.4.7 pyyaml-5.4.1 sacrebleu-2.2.0 sentencepiece-0.1.99 seqeval-1.2.2 tensorflow-addons-0.20.0 tensorflow-model-optimization-0.7.4 tensorflow-text-2.12.1 tensorflow_io-0.32.0 tf-models-official-2.12.0 typeguard-2.13.3 zstandard-0.21.0

# %%
# Cloning a github repository where we can find a python script that can generate these TF Records
# !git clone https://github.com/nicknochnack/GenerateTFRecord
# Out:
# Cloning into 'GenerateTFRecord'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 1 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 2.67 KiB | 2.67 MiB/s, done.

# %%
# Genrate the train.record file that will be used to train the model
# !python GenerateTFRecord/generate_tfrecord.py -x dataset_for_object_detection_model/train/ -l label_map.pbtxt -o train.record
# Out:
# Successfully created the TFRecord file: train.record

# %%
# Genrate the test.record file that will be used to test the model
# !python GenerateTFRecord/generate_tfrecord.py -x dataset_for_object_detection_model/test/ -l label_map.pbtxt -o test.record
# Out:
# Successfully created the TFRecord file: test.record

# %%
# For a better organization and consistency of our work, we will create a new directory named annotations
# that will hold the train.record, test.record and the label_map.pbtxt files.
# !mkdir annotations
# !mv train.record annotations/
# !mv test.record annotations/
# !mv label_map.pbtxt annotations/

# %%
# Now we will create a new directory named my_custom_model that will contain
# our custom trained object detection model later on.
# !mkdir my_custom_model

# %%
# Now we will copy the pipeline.config file from the centernet pretrained model directory 
# to our my_custom_model directory.
# The pipeline.config file will be used to configure the parameters and initial settings needed to train and test the model
# (path to the train.record/test.record files, path to pretrained_model, etc...) 
# !cp centernet_hg104_512x512_coco17_tpu-8/pipeline.config my_custom_model

# %%
# Now we need to finish setting up the the configuration in the pipeline.config file.
# We can do this by manually opening the pipeline.config file in the my_custom_model directory  
# and start configuring the parameters.
# Scroll down slowly through the pipeline.config file and change the parameters as shown.
# The parameters to configure are:
"""
num_classes: 4
image_resizer {
  fixed_shape_resizer {
    height: 512
    width: 512
  }
}
train_config{
  batch_size : 8
  }
fine_tune_checkpoint: "/content/centernet_hg104_512x512_coco17_tpu-8/checkpoint/ckpt-0"
train_input_reader {
  label_map_path : "/content/annotations/label_map.pbtxt"
  input_path : "/content/annotations/train.record"
}
eval_input_reader {
  label_map_path: "/content/annotations/label_map.pbtxt"
  input_path: "/content/annotations/test.record"
}
"""
# We can still configure more of the parameters in the pipeline.config file like the optimizer, num_steps etc...
# But for now, we will just focus on the most important parameters and let the optimisation in the finetuning phase later on.

# %% [markdown]
# ### Training the model

# %%
# !python models/research/object_detection/model_main_tf2.py --model_dir=my_custom_model --pipeline_config_path=my_custom_model/pipeline.config --num_train_steps=5000
# Out:
# 2023-05-17 18:49:59.512154: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-17 18:50:00.981094: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2023-05-17 18:50:04.932611: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 18:50:04.977370: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 18:50:04.977721: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 18:50:04.979971: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 18:50:04.980273: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 18:50:04.980548: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 18:50:06.503337: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 18:50:06.503809: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 18:50:06.504283: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 18:50:06.504473: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-05-17 18:50:06.504535: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13678 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0517 18:50:06.544411 139696591923008 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 5000
# I0517 18:50:06.550293 139696591923008 config_util.py:552] Maybe overwriting train_steps: 5000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0517 18:50:06.550647 139696591923008 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.580203 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.591694 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.815063 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.820656 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.832539 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.836610 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.843211 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.847270 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.853891 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.858013 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.862769 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.869727 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.874205 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.883202 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.887448 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.894053 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.899226 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.907629 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.912005 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.916499 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.924511 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.929469 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.937651 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.943509 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.950106 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.954455 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.961668 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.966126 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.970609 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.977476 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.983970 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.992121 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:06.996866 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.007020 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.013040 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.020864 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.025004 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.029145 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.035439 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.039438 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.047088 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.051034 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.057472 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.061831 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.068712 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.073057 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.077438 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.084358 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.088536 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.095008 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.099625 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.108559 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.113409 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.121362 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.125163 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.131764 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.137133 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.145601 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.150254 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.157046 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.160710 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.164912 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.176352 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.180142 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.186243 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.191223 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.201333 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.205183 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.212342 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.216191 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.222755 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.226503 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.232654 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.236562 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.240663 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.247898 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.251858 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.258218 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.262717 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.270680 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.277995 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.281978 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.289038 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.293161 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 18:50:07.300593 139696591923008 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# ...
# INFO:tensorflow:{'Loss/box/offset': 0.48810422,
#  'Loss/box/scale': 0.19042921,
#  'Loss/object_center': 0.04455059,
#  'Loss/total_loss': 0.72308403,
#  'learning_rate': 0.001}
# I0517 19:45:11.211471 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.48810422,
#  'Loss/box/scale': 0.19042921,
#  'Loss/object_center': 0.04455059,
#  'Loss/total_loss': 0.72308403,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 2100 per-step time 1.877s
# I0517 19:48:18.962188 139696591923008 model_lib_v2.py:705] Step 2100 per-step time 1.877s
# INFO:tensorflow:{'Loss/box/offset': 0.39020264,
#  'Loss/box/scale': 0.22299872,
#  'Loss/object_center': 0.03495773,
#  'Loss/total_loss': 0.6481591,
#  'learning_rate': 0.001}
# I0517 19:48:18.962661 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.39020264,
#  'Loss/box/scale': 0.22299872,
#  'Loss/object_center': 0.03495773,
#  'Loss/total_loss': 0.6481591,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 2200 per-step time 1.530s
# I0517 19:50:51.978456 139696591923008 model_lib_v2.py:705] Step 2200 per-step time 1.530s
# INFO:tensorflow:{'Loss/box/offset': 0.33867356,
#  'Loss/box/scale': 0.18331979,
#  'Loss/object_center': 0.095802784,
#  'Loss/total_loss': 0.6177962,
#  'learning_rate': 0.001}
# I0517 19:50:51.978911 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.33867356,
#  'Loss/box/scale': 0.18331979,
#  'Loss/object_center': 0.095802784,
#  'Loss/total_loss': 0.6177962,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 2300 per-step time 1.534s
# I0517 19:53:25.371798 139696591923008 model_lib_v2.py:705] Step 2300 per-step time 1.534s
# INFO:tensorflow:{'Loss/box/offset': 0.3656202,
#  'Loss/box/scale': 0.25409666,
#  'Loss/object_center': 0.102429666,
#  'Loss/total_loss': 0.7221465,
#  'learning_rate': 0.001}
# I0517 19:53:25.372250 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.3656202,
#  'Loss/box/scale': 0.25409666,
#  'Loss/object_center': 0.102429666,
#  'Loss/total_loss': 0.7221465,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 2400 per-step time 1.535s
# I0517 19:55:58.911670 139696591923008 model_lib_v2.py:705] Step 2400 per-step time 1.535s
# INFO:tensorflow:{'Loss/box/offset': 0.38169184,
#  'Loss/box/scale': 0.17187165,
#  'Loss/object_center': 0.13880676,
#  'Loss/total_loss': 0.6923703,
#  'learning_rate': 0.001}
# I0517 19:55:58.912117 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.38169184,
#  'Loss/box/scale': 0.17187165,
#  'Loss/object_center': 0.13880676,
#  'Loss/total_loss': 0.6923703,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 2500 per-step time 1.537s
# I0517 19:58:32.582501 139696591923008 model_lib_v2.py:705] Step 2500 per-step time 1.537s
# INFO:tensorflow:{'Loss/box/offset': 0.43969214,
#  'Loss/box/scale': 0.26231775,
#  'Loss/object_center': 1.1079695,
#  'Loss/total_loss': 1.8099794,
#  'learning_rate': 0.001}
# I0517 19:58:32.582946 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.43969214,
#  'Loss/box/scale': 0.26231775,
#  'Loss/object_center': 1.1079695,
#  'Loss/total_loss': 1.8099794,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 2600 per-step time 1.536s
# I0517 20:01:06.160846 139696591923008 model_lib_v2.py:705] Step 2600 per-step time 1.536s
# INFO:tensorflow:{'Loss/box/offset': 0.47688898,
#  'Loss/box/scale': 0.22558358,
#  'Loss/object_center': 0.3643582,
#  'Loss/total_loss': 1.0668308,
#  'learning_rate': 0.001}
# I0517 20:01:06.161198 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.47688898,
#  'Loss/box/scale': 0.22558358,
#  'Loss/object_center': 0.3643582,
#  'Loss/total_loss': 1.0668308,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 2700 per-step time 1.537s
# I0517 20:03:39.897652 139696591923008 model_lib_v2.py:705] Step 2700 per-step time 1.537s
# INFO:tensorflow:{'Loss/box/offset': 0.43446434,
#  'Loss/box/scale': 0.30450416,
#  'Loss/object_center': 0.10587713,
#  'Loss/total_loss': 0.84484565,
#  'learning_rate': 0.001}
# I0517 20:03:39.898095 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.43446434,
#  'Loss/box/scale': 0.30450416,
#  'Loss/object_center': 0.10587713,
#  'Loss/total_loss': 0.84484565,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 2800 per-step time 1.536s
# I0517 20:06:13.443807 139696591923008 model_lib_v2.py:705] Step 2800 per-step time 1.536s
# INFO:tensorflow:{'Loss/box/offset': 0.44142616,
#  'Loss/box/scale': 0.24634302,
#  'Loss/object_center': 0.06715464,
#  'Loss/total_loss': 0.7549238,
#  'learning_rate': 0.001}
# I0517 20:06:13.444162 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.44142616,
#  'Loss/box/scale': 0.24634302,
#  'Loss/object_center': 0.06715464,
#  'Loss/total_loss': 0.7549238,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 2900 per-step time 1.535s
# I0517 20:08:46.982516 139696591923008 model_lib_v2.py:705] Step 2900 per-step time 1.535s
# INFO:tensorflow:{'Loss/box/offset': 0.38181597,
#  'Loss/box/scale': 0.22339538,
#  'Loss/object_center': 0.07587205,
#  'Loss/total_loss': 0.6810834,
#  'learning_rate': 0.001}
# I0517 20:08:46.982959 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.38181597,
#  'Loss/box/scale': 0.22339538,
#  'Loss/object_center': 0.07587205,
#  'Loss/total_loss': 0.6810834,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 3000 per-step time 1.534s
# I0517 20:11:20.367082 139696591923008 model_lib_v2.py:705] Step 3000 per-step time 1.534s
# INFO:tensorflow:{'Loss/box/offset': 0.3989203,
#  'Loss/box/scale': 0.1917787,
#  'Loss/object_center': 0.035048764,
#  'Loss/total_loss': 0.6257478,
#  'learning_rate': 0.001}
# I0517 20:11:20.367500 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.3989203,
#  'Loss/box/scale': 0.1917787,
#  'Loss/object_center': 0.035048764,
#  'Loss/total_loss': 0.6257478,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 3100 per-step time 2.010s
# I0517 20:14:41.378155 139696591923008 model_lib_v2.py:705] Step 3100 per-step time 2.010s
# INFO:tensorflow:{'Loss/box/offset': 0.34578434,
#  'Loss/box/scale': 0.22171262,
#  'Loss/object_center': 0.017517766,
#  'Loss/total_loss': 0.5850147,
#  'learning_rate': 0.001}
# I0517 20:14:41.378644 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.34578434,
#  'Loss/box/scale': 0.22171262,
#  'Loss/object_center': 0.017517766,
#  'Loss/total_loss': 0.5850147,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 3200 per-step time 1.528s
# I0517 20:17:14.164572 139696591923008 model_lib_v2.py:705] Step 3200 per-step time 1.528s
# INFO:tensorflow:{'Loss/box/offset': 0.48348635,
#  'Loss/box/scale': 0.4741269,
#  'Loss/object_center': 0.25860143,
#  'Loss/total_loss': 1.2162147,
#  'learning_rate': 0.001}
# I0517 20:17:14.165025 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.48348635,
#  'Loss/box/scale': 0.4741269,
#  'Loss/object_center': 0.25860143,
#  'Loss/total_loss': 1.2162147,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 3300 per-step time 1.538s
# I0517 20:19:48.012706 139696591923008 model_lib_v2.py:705] Step 3300 per-step time 1.538s
# INFO:tensorflow:{'Loss/box/offset': 0.28912705,
#  'Loss/box/scale': 0.47509795,
#  'Loss/object_center': 0.42385432,
#  'Loss/total_loss': 1.1880794,
#  'learning_rate': 0.001}
# I0517 20:19:48.013150 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.28912705,
#  'Loss/box/scale': 0.47509795,
#  'Loss/object_center': 0.42385432,
#  'Loss/total_loss': 1.1880794,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 3400 per-step time 1.537s
# I0517 20:22:21.699944 139696591923008 model_lib_v2.py:705] Step 3400 per-step time 1.537s
# INFO:tensorflow:{'Loss/box/offset': 0.3385042,
#  'Loss/box/scale': 0.1979333,
#  'Loss/object_center': 0.051437013,
#  'Loss/total_loss': 0.58787453,
#  'learning_rate': 0.001}
# I0517 20:22:21.700378 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.3385042,
#  'Loss/box/scale': 0.1979333,
#  'Loss/object_center': 0.051437013,
#  'Loss/total_loss': 0.58787453,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 3500 per-step time 1.539s
# I0517 20:24:55.559705 139696591923008 model_lib_v2.py:705] Step 3500 per-step time 1.539s
# INFO:tensorflow:{'Loss/box/offset': 0.2907842,
#  'Loss/box/scale': 0.23646589,
#  'Loss/object_center': 0.025999509,
#  'Loss/total_loss': 0.5532496,
#  'learning_rate': 0.001}
# I0517 20:24:55.560075 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.2907842,
#  'Loss/box/scale': 0.23646589,
#  'Loss/object_center': 0.025999509,
#  'Loss/total_loss': 0.5532496,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 3600 per-step time 1.539s
# I0517 20:27:29.499936 139696591923008 model_lib_v2.py:705] Step 3600 per-step time 1.539s
# INFO:tensorflow:{'Loss/box/offset': 0.38776034,
#  'Loss/box/scale': 0.34465155,
#  'Loss/object_center': 0.1252871,
#  'Loss/total_loss': 0.857699,
#  'learning_rate': 0.001}
# I0517 20:27:29.500323 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.38776034,
#  'Loss/box/scale': 0.34465155,
#  'Loss/object_center': 0.1252871,
#  'Loss/total_loss': 0.857699,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 3700 per-step time 1.536s
# I0517 20:30:03.077128 139696591923008 model_lib_v2.py:705] Step 3700 per-step time 1.536s
# INFO:tensorflow:{'Loss/box/offset': 0.41428235,
#  'Loss/box/scale': 0.22741087,
#  'Loss/object_center': 0.05928437,
#  'Loss/total_loss': 0.70097756,
#  'learning_rate': 0.001}
# I0517 20:30:03.077589 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.41428235,
#  'Loss/box/scale': 0.22741087,
#  'Loss/object_center': 0.05928437,
#  'Loss/total_loss': 0.70097756,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 3800 per-step time 1.536s
# I0517 20:32:36.649482 139696591923008 model_lib_v2.py:705] Step 3800 per-step time 1.536s
# INFO:tensorflow:{'Loss/box/offset': 0.25221622,
#  'Loss/box/scale': 0.1560518,
#  'Loss/object_center': 0.02104811,
#  'Loss/total_loss': 0.42931613,
#  'learning_rate': 0.001}
# I0517 20:32:36.649857 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.25221622,
#  'Loss/box/scale': 0.1560518,
#  'Loss/object_center': 0.02104811,
#  'Loss/total_loss': 0.42931613,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 3900 per-step time 1.538s
# I0517 20:35:10.492581 139696591923008 model_lib_v2.py:705] Step 3900 per-step time 1.538s
# INFO:tensorflow:{'Loss/box/offset': 0.3181319,
#  'Loss/box/scale': 0.2762641,
#  'Loss/object_center': 0.043898977,
#  'Loss/total_loss': 0.63829494,
#  'learning_rate': 0.001}
# I0517 20:35:10.492963 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.3181319,
#  'Loss/box/scale': 0.2762641,
#  'Loss/object_center': 0.043898977,
#  'Loss/total_loss': 0.63829494,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 4000 per-step time 1.539s
# I0517 20:37:44.370993 139696591923008 model_lib_v2.py:705] Step 4000 per-step time 1.539s
# INFO:tensorflow:{'Loss/box/offset': 0.4330794,
#  'Loss/box/scale': 0.22837818,
#  'Loss/object_center': 0.021501044,
#  'Loss/total_loss': 0.6829586,
#  'learning_rate': 0.001}
# I0517 20:37:44.371474 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.4330794,
#  'Loss/box/scale': 0.22837818,
#  'Loss/object_center': 0.021501044,
#  'Loss/total_loss': 0.6829586,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 4100 per-step time 2.430s
# I0517 20:41:47.315959 139696591923008 model_lib_v2.py:705] Step 4100 per-step time 2.430s
# INFO:tensorflow:{'Loss/box/offset': 0.28619435,
#  'Loss/box/scale': 0.25645015,
#  'Loss/object_center': 0.09115561,
#  'Loss/total_loss': 0.63380015,
#  'learning_rate': 0.001}
# I0517 20:41:47.316347 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.28619435,
#  'Loss/box/scale': 0.25645015,
#  'Loss/object_center': 0.09115561,
#  'Loss/total_loss': 0.63380015,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 4200 per-step time 1.542s
# I0517 20:44:21.495928 139696591923008 model_lib_v2.py:705] Step 4200 per-step time 1.542s
# INFO:tensorflow:{'Loss/box/offset': 0.4001298,
#  'Loss/box/scale': 0.27470836,
#  'Loss/object_center': 0.027010433,
#  'Loss/total_loss': 0.7018486,
#  'learning_rate': 0.001}
# I0517 20:44:21.496392 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.4001298,
#  'Loss/box/scale': 0.27470836,
#  'Loss/object_center': 0.027010433,
#  'Loss/total_loss': 0.7018486,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 4300 per-step time 1.543s
# I0517 20:46:55.775556 139696591923008 model_lib_v2.py:705] Step 4300 per-step time 1.543s
# INFO:tensorflow:{'Loss/box/offset': 0.28517726,
#  'Loss/box/scale': 0.26683632,
#  'Loss/object_center': 0.04462055,
#  'Loss/total_loss': 0.59663415,
#  'learning_rate': 0.001}
# I0517 20:46:55.775968 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.28517726,
#  'Loss/box/scale': 0.26683632,
#  'Loss/object_center': 0.04462055,
#  'Loss/total_loss': 0.59663415,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 4400 per-step time 1.539s
# I0517 20:49:29.694518 139696591923008 model_lib_v2.py:705] Step 4400 per-step time 1.539s
# INFO:tensorflow:{'Loss/box/offset': 0.30465505,
#  'Loss/box/scale': 0.2245179,
#  'Loss/object_center': 0.049417756,
#  'Loss/total_loss': 0.5785907,
#  'learning_rate': 0.001}
# I0517 20:49:29.695040 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.30465505,
#  'Loss/box/scale': 0.2245179,
#  'Loss/object_center': 0.049417756,
#  'Loss/total_loss': 0.5785907,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 4500 per-step time 1.540s
# I0517 20:52:03.735318 139696591923008 model_lib_v2.py:705] Step 4500 per-step time 1.540s
# INFO:tensorflow:{'Loss/box/offset': 0.45411375,
#  'Loss/box/scale': 0.20408216,
#  'Loss/object_center': 0.0675614,
#  'Loss/total_loss': 0.72575736,
#  'learning_rate': 0.001}
# I0517 20:52:03.735752 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.45411375,
#  'Loss/box/scale': 0.20408216,
#  'Loss/object_center': 0.0675614,
#  'Loss/total_loss': 0.72575736,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 4600 per-step time 1.540s
# I0517 20:54:37.697124 139696591923008 model_lib_v2.py:705] Step 4600 per-step time 1.540s
# INFO:tensorflow:{'Loss/box/offset': 0.32138318,
#  'Loss/box/scale': 0.20370737,
#  'Loss/object_center': 0.03534518,
#  'Loss/total_loss': 0.5604357,
#  'learning_rate': 0.001}
# I0517 20:54:37.697474 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.32138318,
#  'Loss/box/scale': 0.20370737,
#  'Loss/object_center': 0.03534518,
#  'Loss/total_loss': 0.5604357,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 4700 per-step time 1.539s
# I0517 20:57:11.616924 139696591923008 model_lib_v2.py:705] Step 4700 per-step time 1.539s
# INFO:tensorflow:{'Loss/box/offset': 0.35367376,
#  'Loss/box/scale': 0.20564842,
#  'Loss/object_center': 0.042951487,
#  'Loss/total_loss': 0.6022737,
#  'learning_rate': 0.001}
# I0517 20:57:11.617358 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.35367376,
#  'Loss/box/scale': 0.20564842,
#  'Loss/object_center': 0.042951487,
#  'Loss/total_loss': 0.6022737,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 4800 per-step time 1.542s
# I0517 20:59:45.858746 139696591923008 model_lib_v2.py:705] Step 4800 per-step time 1.542s
# INFO:tensorflow:{'Loss/box/offset': 0.30285376,
#  'Loss/box/scale': 0.14896302,
#  'Loss/object_center': 0.040264726,
#  'Loss/total_loss': 0.49208152,
#  'learning_rate': 0.001}
# I0517 20:59:45.859282 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.30285376,
#  'Loss/box/scale': 0.14896302,
#  'Loss/object_center': 0.040264726,
#  'Loss/total_loss': 0.49208152,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 4900 per-step time 1.540s
# I0517 21:02:19.842087 139696591923008 model_lib_v2.py:705] Step 4900 per-step time 1.540s
# INFO:tensorflow:{'Loss/box/offset': 0.3815183,
#  'Loss/box/scale': 0.18735734,
#  'Loss/object_center': 0.10955776,
#  'Loss/total_loss': 0.6784334,
#  'learning_rate': 0.001}
# I0517 21:02:19.842624 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.3815183,
#  'Loss/box/scale': 0.18735734,
#  'Loss/object_center': 0.10955776,
#  'Loss/total_loss': 0.6784334,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 5000 per-step time 1.540s
# I0517 21:04:53.873675 139696591923008 model_lib_v2.py:705] Step 5000 per-step time 1.540s
# INFO:tensorflow:{'Loss/box/offset': 0.30006778,
#  'Loss/box/scale': 0.17692697,
#  'Loss/object_center': 0.020838177,
#  'Loss/total_loss': 0.49783292,
#  'learning_rate': 0.001}
# I0517 21:04:53.874250 139696591923008 model_lib_v2.py:708] {'Loss/box/offset': 0.30006778,
#  'Loss/box/scale': 0.17692697,
#  'Loss/object_center': 0.020838177,
#  'Loss/total_loss': 0.49783292,
#  'learning_rate': 0.001}

# %% [markdown]
# ### Testing the model

# %%
# !python models/research/object_detection/model_main_tf2.py --model_dir=my_custom_model --pipeline_config_path=my_custom_model/pipeline.config --checkpoint_dir=my_custom_model
# Out:
# Traceback (most recent call last):
#   File "/content/models/research/object_detection/model_main_tf2.py", line 114, in <module>
#     tf.compat.v1.app.run()
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/platform/app.py", line 36, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.10/dist-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.10/dist-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "/content/models/research/object_detection/model_main_tf2.py", line 81, in main
#     model_lib_v2.eval_continuously(
#   File "/usr/local/lib/python3.10/dist-packages/object_detection/model_lib_v2.py", line 1135, in eval_continuously
#     for latest_checkpoint in tf.train.checkpoints_iterator(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/training/checkpoint_utils.py", line 244, in checkpoints_iterator
# KeyboardInterrupt
# ^C

# %%
### Average Precision of 76% is not bad for a start.

# %% [markdown]
# ### Exporting the model

# %%
# Creating a directory named object_detection_model that will contain our trained model
# !mkdir object_detection_model

# %%
# freezing the model
# !python models/research/object_detection/exporter_main_v2.py --input_type=image_tensor --pipeline_config_path=my_custom_model/pipeline.config --trained_checkpoint_dir=my_custom_model --output_directory=object_detection_model
# Out:
# 2023-05-17 21:09:45.005761: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-17 21:09:46.617748: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2023-05-17 21:09:49.464886: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:09:49.501087: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:09:49.501412: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:09:49.510167: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:09:49.510547: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:09:49.510787: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:09:50.616651: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:09:50.617040: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:09:50.617270: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:09:50.617417: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-05-17 21:09:50.617470: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13678 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.648011 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.655806 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.658529 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.662260 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.670832 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.673696 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.678478 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.681360 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.686246 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.689131 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.692314 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.697988 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.700805 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.705962 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.709120 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.713621 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.716459 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.720749 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.723298 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.725970 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.730941 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.733499 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.738655 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.741326 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.745388 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.748044 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.752651 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.755466 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.758159 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.762260 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.764808 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.769946 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.773469 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.777654 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.780132 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.784310 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.786765 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.789495 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.793774 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.796451 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.801327 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.804085 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.808123 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.810698 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.815893 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.818325 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:50.820893 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.008531 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.011349 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.015819 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.018312 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.022413 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.025011 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.029031 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.031539 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.035542 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.037908 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.042034 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.044475 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.048315 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.050780 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.054952 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.064686 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.067208 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.071033 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.073467 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.078146 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.080557 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.084451 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.086799 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.091280 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.093794 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.097666 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.101380 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.104090 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.108511 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.111153 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.115160 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.117627 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.121983 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.126182 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.129027 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.139890 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.142706 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.146831 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.149260 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# ...
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.367211 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.370090 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.374346 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.377049 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.379787 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.384631 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.387170 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.391208 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.393746 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.398308 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.401713 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.404783 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.409183 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:09:51.413136 139863504709440 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0517 21:09:51.654777 139863504709440 deprecation.py:641] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.center_net_meta_arch.CenterNetMetaArch object at 0x7f33882af640>, because it is not built.
# W0517 21:10:16.524706 139863504709440 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.center_net_meta_arch.CenterNetMetaArch object at 0x7f33882af640>, because it is not built.
# 2023-05-17 21:10:25.551676: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:10:26.117911: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:10:26.699341: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:10:27.172168: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:10:27.915217: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:10:33.168041: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:10:33.537413: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:10:34.401361: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:10:34.890514: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:10:35.257455: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:11:45.251394: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:11:45.351515: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:11:46.613838: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:11:47.272158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:11:50.143137: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:11:50.764136: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:11:52.911724: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:11:53.535490: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:11:55.884647: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:11:56.742933: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# W0517 21:12:05.475505 139863504709440 save.py:274] Found untraced functions such as convolutional_block_layer_call_fn, convolutional_block_layer_call_and_return_conditional_losses, residual_block_layer_call_fn, residual_block_layer_call_and_return_conditional_losses, _jit_compiled_convolution_op while saving (showing 5 of 1302). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: object_detection_model/saved_model/assets
# I0517 21:13:13.069047 139863504709440 builder_impl.py:797] Assets written to: object_detection_model/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to object_detection_model/pipeline.config
# I0517 21:13:21.286045 139863504709440 config_util.py:253] Writing pipeline config file to object_detection_model/pipeline.config

# %% [markdown]
# ### Convert our model to TFLite
# #### TFLite is a lighter version of our model which can be deployed in an embedded system such as a raspberry pi

# %%
# !python models/research/object_detection/export_tflite_graph_tf2.py  --pipeline_config_path=object_detection_model/pipeline.config --trained_checkpoint_dir=object_detection_model/checkpoint checkpoint --output_directory=object_detection_model_tflite
# Out:
# 2023-05-17 21:31:00.071386: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-17 21:31:01.768902: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2023-05-17 21:31:05.397647: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:31:05.432302: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:31:05.432665: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:31:05.442413: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:31:05.442875: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:31:05.443126: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:31:06.569498: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:31:06.569873: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:31:06.570215: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:31:06.570414: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-05-17 21:31:06.570487: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13678 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.599762 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.607477 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.610447 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.614042 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.622146 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.624759 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.628914 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.631618 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.635993 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.638540 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.641597 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.645651 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.648293 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.653686 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.656434 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.660557 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.663041 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.666945 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.669436 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.672600 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.676608 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.679181 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.683851 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.686342 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.690072 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.692521 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.696615 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.699133 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.701755 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.705814 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.708319 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.713136 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.715738 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.719577 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.722329 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.726890 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.730290 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.733784 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.738204 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.740954 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.745859 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.748433 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.752634 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.755256 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.759369 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.762896 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.765630 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.769624 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.947963 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.952255 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.954958 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.958967 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.961535 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.965707 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.968222 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.972004 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.974524 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.978576 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.981174 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.988060 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.992120 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:06.996223 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.003868 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.006411 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.010391 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.013067 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.017878 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.020603 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.024697 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.027343 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.032325 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.034978 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.039087 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.041649 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.044325 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.049927 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.052479 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.056671 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.059180 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.063367 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.067871 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.070369 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.074423 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.077043 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.081047 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.083787 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# ...
# W0517 21:31:07.290342 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.294923 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.298697 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.304911 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.309119 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.317044 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.321803 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.326481 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.334361 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.338241 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.343527 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.347147 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.353895 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.360353 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.365130 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.370249 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0517 21:31:07.374544 139855351502656 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.center_net_meta_arch.CenterNetMetaArch object at 0x7f31a34e9960>, because it is not built.
# W0517 21:31:26.802088 139855351502656 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.center_net_meta_arch.CenterNetMetaArch object at 0x7f31a34e9960>, because it is not built.
# 2023-05-17 21:31:35.523673: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:31:36.127439: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:31:36.734547: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:31:37.436916: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:31:38.032544: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:31:43.683973: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:31:44.044685: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:31:44.440728: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:31:44.888697: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:31:45.773441: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:32:57.546728: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:32:57.728188: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:32:59.507678: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:33:00.158422: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:33:02.200200: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:33:02.813817: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:33:04.998480: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:33:06.493889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:33:08.451892: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# 2023-05-17 21:33:09.013057: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,?,?,?]
# 	 [[{{node inputs}}]]
# W0517 21:33:18.532698 139855351502656 save.py:274] Found untraced functions such as convolutional_block_layer_call_fn, convolutional_block_layer_call_and_return_conditional_losses, residual_block_layer_call_fn, residual_block_layer_call_and_return_conditional_losses, _jit_compiled_convolution_op while saving (showing 5 of 1302). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: object_detection_model_tflite/saved_model/assets
# I0517 21:34:56.778664 139855351502656 builder_impl.py:797] Assets written to: object_detection_model_tflite/saved_model/assets

# %%
# !tflite_convert --saved_model_dir=object_detection_model_tflite/saved_model --output_file=object_detection_model_tflite/saved_model/object_detection_model.tflite --input_shapes=1,512,512,3 --input_arrays=normalized_input_image_tensor --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' --inference_type=FLOAT --allow_custom_ops
# Out:
# 2023-05-17 21:35:26.842859: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-17 21:35:28.132473: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-05-17 21:35:29.932694: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:35:29.978903: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:35:29.979192: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# W0517 21:35:33.741456 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_182369) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 2023-05-17 21:35:33.841192: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:35:33.841560: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:35:33.841786: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:35:35.278662: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:35:35.279098: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:35:35.279535: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-17 21:35:35.279726: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-05-17 21:35:35.279798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13678 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# W0517 21:35:35.296663 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_184129) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.300466 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_184479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.303808 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_182969) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.307391 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_185119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.310871 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_163699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.314379 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_164889) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.318061 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_189649) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.332288 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_172959) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.335535 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_187689) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.338659 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_173019) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.341748 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_166189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.345336 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_171109) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.348783 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183629) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.352137 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_180439) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.355888 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_173419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.364673 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_168669) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.375642 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_179099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.379098 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_180499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.382405 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_175299) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.385964 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_170269) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.389410 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_186459) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.392520 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_180469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.396075 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_172149) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.411102 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_178949) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.414492 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_182219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.417904 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183669) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.420933 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_176989) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.424176 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_184679) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.427667 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_173059) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.430962 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.434250 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_174819) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.437430 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_168119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.441074 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_182089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.444522 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_184929) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.447992 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_188959) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.452382 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_167379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.457280 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_169559) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.462050 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.465914 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_185659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.469609 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_179059) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.473421 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_187039) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.478417 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_190289) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.491624 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_184289) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.495147 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_174979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.498563 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_175269) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.501932 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_178919) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.505593 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_177719) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.509115 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_189139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.512630 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_166809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.528890 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_189849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.548036 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_171749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.551699 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_188679) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.555103 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_185159) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.560053 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_168849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.563278 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_179209) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.567067 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183889) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.570553 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_179609) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.574238 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_172379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.577908 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183289) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.587012 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_189609) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.590557 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_189369) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.593999 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183509) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.603684 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_191969) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.607371 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_169099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.611190 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_172259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.614946 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_177329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.618989 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_176599) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.629426 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_181889) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.633866 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_166179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.637679 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_191899) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.657140 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_191179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.661283 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183299) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.665485 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_176779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.669729 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_170099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.673722 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_186899) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.680891 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_180129) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.715471 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_189059) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.719559 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_177249) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.723387 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_172909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.729192 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_165719) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.733945 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_186499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.738262 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_178789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.742419 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_180669) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.746471 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_167069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.752140 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_179299) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.756348 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_181149) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.760246 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_174289) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.764430 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_192209) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.768839 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_171089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.772872 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_177809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.776972 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_170809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.780957 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_175049) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.785301 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_192019) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.792727 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_185759) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.796630 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_176479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.811494 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_181849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.815377 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_167429) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.826885 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_177459) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.843807 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_173119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.887853 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_165279) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.891706 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_186849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.895809 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_186349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.903020 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_168649) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.907027 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_181989) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.911034 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_177969) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.914839 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_167809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.919057 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_180079) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.923072 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_173049) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.927050 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_186079) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.931450 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_170439) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.935206 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_178039) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.939024 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_179679) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.946089 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_186379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.949963 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_187409) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.953877 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_164159) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.958938 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_187499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.962635 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_166429) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.966365 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_180349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.970084 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_166009) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.979829 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_184319) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.986806 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_188639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.990458 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_188109) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.993803 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_187609) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:35.997525 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_172999) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.001076 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.011606 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_191349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.021903 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_173149) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.025475 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_171359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.035755 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_169349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.039319 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_175519) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.042831 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_176329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.046431 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_185029) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.050110 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_169069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.054115 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_185309) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.058696 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_180999) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.063468 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_177399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.068171 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_167239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.072591 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_169789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.076612 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_169539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.080229 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_179399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.084264 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_173219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.108363 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_168069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.111702 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_188059) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.115315 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_167319) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.118803 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_175039) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.129434 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_170089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.132953 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_173539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.136575 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_189969) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.140105 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_167579) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.143556 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_180699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.148791 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_175279) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.164190 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_167979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.171152 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_188069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.174791 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_166149) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.177580 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_175839) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.180515 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_178379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.183961 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_174919) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.187375 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_177639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.201521 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_164119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.205161 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_166929) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.208540 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_182429) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.212274 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_186619) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.215977 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_166589) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.219578 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_165639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.229050 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_173769) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.232405 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_181179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.235831 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_164699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.239356 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_188169) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.248504 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_176319) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.251763 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_186919) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.255568 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_171399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.258975 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_190799) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.262867 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_175419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.266475 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_187469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.270456 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_177789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.280231 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_181499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.285848 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_171639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.289782 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_166019) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.293691 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_173239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.297571 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_172299) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.301144 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_164719) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.305162 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_171339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.308773 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_190699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.312987 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_190759) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.316840 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_166759) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.320829 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_167939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.324702 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_169399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.328498 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_171839) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.335393 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.340275 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_168359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.344073 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_178529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.347809 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_182189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.351533 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_170069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.355415 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.365298 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_185409) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.369033 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_179239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.372832 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.376356 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_176259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.379715 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_173759) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.383529 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_170249) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.387223 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_172429) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.393759 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_184219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:35:36.397445 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_182179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# W0517 21:36:04.043584 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_189909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.046103 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_184559) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.048774 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_167759) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.065280 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_168439) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.095522 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_186939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.098303 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_185749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.101114 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_176909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.103859 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_177729) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.106482 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_165809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.126258 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_189899) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.129256 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183039) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.132031 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_186259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.134843 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_163759) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.154605 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_173449) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.157679 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_171799) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.179052 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_185269) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:04.182061 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_182059) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.151597 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_179829) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.154903 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.157954 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_165589) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.174968 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_187729) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.178124 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_169699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.199110 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_185859) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.202024 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_169679) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.219548 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_182949) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.222667 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_168869) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.247797 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_179389) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.250498 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_166139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.269334 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_185009) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.273357 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_177199) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.276204 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_174889) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.286735 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_173279) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.308613 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_170029) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.329946 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_185829) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.332663 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_170179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.354129 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_176789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.402784 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_166699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.441360 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_192169) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.444140 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_178089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.446562 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_171479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.462934 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_169939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.485585 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_171659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.500188 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_185699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.502352 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_185049) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.504534 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_170719) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.521612 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_167389) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.535246 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_165359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.549715 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_169169) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.567938 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_168259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.587239 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_187649) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.590629 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_171389) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.610171 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_187589) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.612697 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_189399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.615110 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_177429) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.617351 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_173949) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:05.632992 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_179739) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:06.529629 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_165439) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:06.555431 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_170609) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:06.573987 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_174929) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:06.576465 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_190639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:08.466068 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_177529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:10.678149 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_165569) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:10.699888 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_171099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:10.718127 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_174809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:12.252483 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_183789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:12.256895 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_187099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W0517 21:36:12.260623 140392169109312 function_deserialization.py:611] Importing a function (__inference_internal_grad_fn_184189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 2023-05-17 21:36:30.119038: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# 2023-05-17 21:36:30.119086: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2023-05-17 21:36:30.119959: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: object_detection_model_tflite/saved_model
# 2023-05-17 21:36:30.424190: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2023-05-17 21:36:30.424264: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: object_detection_model_tflite/saved_model
# 2023-05-17 21:36:31.242966: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:353] MLIR V1 optimization pass is not enabled
# 2023-05-17 21:36:31.414970: I tensorflow/cc/saved_model/loader.cc:231] Restoring SavedModel bundle.
# 2023-05-17 21:36:35.169043: I tensorflow/cc/saved_model/loader.cc:215] Running initialization op on SavedModel bundle at path: object_detection_model_tflite/saved_model
# 2023-05-17 21:36:36.738888: I tensorflow/cc/saved_model/loader.cc:314] SavedModel load for tags { serve }; Status: success: OK. Took 6618933 microseconds.
# 2023-05-17 21:36:40.937362: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-17 21:36:48.102978: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:2116] Estimated count of arithmetic ops: 526.305 G  ops, equivalently 263.152 G  MACs

# %% [markdown]
# ### Compressing and exporting our models

# %%
# !cp /content/annotations/label_map.pbtxt object_detection_model

# %%
# !zip -r object_detection_model.zip object_detection_model
# !cp object_detection_model.zip drive/MyDrive
# Out:
#   adding: object_detection_model/ (stored 0%)
#   adding: object_detection_model/pipeline.config (deflated 68%)
#   adding: object_detection_model/saved_model/ (stored 0%)
#   adding: object_detection_model/saved_model/variables/ (stored 0%)
#   adding: object_detection_model/saved_model/variables/variables.index (deflated 80%)
#   adding: object_detection_model/saved_model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: object_detection_model/saved_model/assets/ (stored 0%)
#   adding: object_detection_model/saved_model/saved_model.pb (deflated 95%)
#   adding: object_detection_model/saved_model/fingerprint.pb (stored 0%)
#   adding: object_detection_model/checkpoint/ (stored 0%)
#   adding: object_detection_model/checkpoint/ckpt-0.data-00000-of-00001 (deflated 7%)
#   adding: object_detection_model/checkpoint/ckpt-0.index (deflated 83%)
#   adding: object_detection_model/checkpoint/checkpoint (deflated 41%)
#   adding: object_detection_model/label_map.pbtxt (deflated 50%)

# %%
# !cp /content/annotations/label_map.pbtxt object_detection_model_tflite

# %%
# !zip -r object_detection_model_tflite.zip object_detection_model_tflite
# !cp object_detection_model_tflite.zip drive/MyDrive
# Out:
#   adding: object_detection_model_tflite/ (stored 0%)
#   adding: object_detection_model_tflite/saved_model/ (stored 0%)
#   adding: object_detection_model_tflite/saved_model/variables/ (stored 0%)
#   adding: object_detection_model_tflite/saved_model/variables/variables.index (deflated 80%)
#   adding: object_detection_model_tflite/saved_model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: object_detection_model_tflite/saved_model/assets/ (stored 0%)
#   adding: object_detection_model_tflite/saved_model/object_detection_model.tflite (deflated 7%)
#   adding: object_detection_model_tflite/saved_model/saved_model.pb (deflated 95%)
#   adding: object_detection_model_tflite/saved_model/fingerprint.pb (stored 0%)
